# %% [markdown]
# ###Lab 2.
# ####Stage 1

# %% [markdown]
# Storage Account (ADLS Gen2):

# %% [markdown]
# ![Storage Account](./stage1/storage_account1.png)

# %% [markdown]
# Key Vault:

# %% [markdown]
# ![Key Vault](./stage1/key_vault1.png)

# %% [markdown]
# Databricks workspace:

# %% [markdown]
# ![Databricks Workspace](./stage1/databricks_workspace1.png)
