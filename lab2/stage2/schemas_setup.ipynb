# %%
# %sql
CATALOG_NAME = 'dbr_dev_ua5816bd'
STORAGE_ACCOUNT = 'dlsua5816bd'
LOGIN = 'elinasharabura'

CREATE SCHEMA IF NOT EXISTS {CATALOG_NAME}.elina_sharabura_bronze
MANAGED LOCATION 'abfss://{LOGIN}@{STORAGE_ACCOUNT}.dfs.core.windows.net/bronze';

CREATE SCHEMA IF NOT EXISTS {CATALOG_NAME}.elina_sharabura_silver
MANAGED LOCATION 'abfss://{LOGIN}@{STORAGE_ACCOUNT}.dfs.core.windows.net/silver';

CREATE SCHEMA IF NOT EXISTS {CATALOG_NAME}.elina_sharabura_gold
MANAGED LOCATION 'abfss://{LOGIN}@{STORAGE_ACCOUNT}.dfs.core.windows.net/gold';

# %%
# %sql
SHOW SCHEMAS IN dbr_dev_ua5816bd LIKE '*elina_sharabura*';

# %%
# %sql
SHOW CATALOGS;

# %%
dbutils.secrets.listScopes()
